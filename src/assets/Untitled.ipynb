# %%
import geopandas as gpd
import geojson

gdf = gpd.read_file('./StudyAreas/StudyAreas.shp')
print(gdf)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-460894dc60d0> in <module>
# ----> 1 import geopandas as gpd
#       2 import geojson
#       3
#       4 gdf = gpd.read_file('./StudyAreas/StudyAreas.shp')
#       5 print(gdf)
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/__init__.py in <module>
# ----> 1 from geopandas.geoseries import GeoSeries
#       2 from geopandas.geodataframe import GeoDataFrame
#       3 from geopandas.geodataframe import points_from_xy
#       4
#       5 from geopandas.io.file import read_file
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/geoseries.py in <module>
#       3 import json
#       4
# ----> 5 import numpy as np
#       6 from pandas import Series
#       7 import pyproj
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/__init__.py in <module>
#     140     from . import _distributor_init
#     141
# ...

# %%
# !conda install numpy -y
# Out:
# ...
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::pysal==2.0.0=py_0
#   - pyviz/noarch::geoviews-core==1.6.2=py_0
#   - conda-forge/noarch::regionmask==0.4.0=py_0
#   - defaults/linux-64::keyring==17.0.0=py37_0
#   - defaults/linux-64::conda-build==3.17.6=py37_0
#   - defaults/linux-64::libarchive==3.3.3=h5d8350f_5
#   - defaults/linux-64::numpy-base==1.15.4=py37hde5b4d6_0
#   - conda-forge/linux-64::iris==2.2.0=py37_1003
#   - defaults/linux-64::mkl_fft==1.0.6=py37hd81dba3_0
#   - defaults/linux-64::qtconsole==4.4.3=py37_0
#   - defaults/linux-64::pyqt==5.9.2=py37h05f1152_2
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - conda-forge/linux-64::netcdf4==1.4.3.2=py37h597e859_0
#   - defaults/linux-64::anaconda-navigator==1.9.6=py37_0
#   - pyviz/noarch::holoviews==1.12.2=py_0
#   - defaults/linux-64::harfbuzz==1.8.8=hffaf4a1_0
# ...

# %%
# !ls StudyAreas
# Out:
# StudyAreas.cpg	StudyAreas.prj	StudyAreas.sbx	StudyAreas.shp.xml
# StudyAreas.dbf	StudyAreas.sbn	StudyAreas.shp	StudyAreas.shx
